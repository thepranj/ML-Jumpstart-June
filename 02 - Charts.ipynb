# %% [markdown]
# # Charts

# %%
from verticapy import *

# %%
from verticapy.connections import *
new_auto_connection({"host": "34.237.154.116", 
                     "port": "5433", 
                     "database": "testdrive", 
                     "password": "password", 
                     "user": "dbadmin"},
                    name = "VerticaDSN")
# Set the primary auto-connection
change_auto_connection("VerticaDSN")

# %% [markdown]
# ## Regular Charts

# %%
read_csv('iris.csv',
          schema = 'public',
          table_name = 'iris')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e24e0301061a> in <module>
# ----> 1 read_csv('iris.csv',
#       2           schema = 'public',
#       3           table_name = 'iris')
#
# c:\users\psingh5\appdata\local\programs\python\python38-32\lib\site-packages\verticapy\utilities.py in read_csv(path, cursor, schema, table_name, sep, header, header_names, dtype, na_rep, quotechar, escape, genSQL, parse_n_lines, insert)
#     771     result = cursor.fetchall()
#     772     if (result != []) and not (insert):
# --> 773         raise NameError(
#     774             'The table "{}"."{}" already exists !'.format(schema, table_name)
#     775         )
#
# NameError: The table "public"."iris" already exists !

# %%
# %matplotlib inline

# %%
vdf = vDataFrame("public.titanic")
vdf["pclass"].hist()
#vdf["pclass"].pie()

# %% [markdown]
# These methods will draw the most occurent categories and merge the others. To change the number of elements to display, you should use the 'max_cardinality' parameter.

# %%
vdf["home.dest"].hist()
vdf["home.dest"].hist(max_cardinality = 20)

# %% [markdown]
# When dealing with numerical data types, the process is different. Vertica needs to discretize the numerical features to draw them. You can choose the bar width ('h' parameter) or let VerticaPy compute an optimal one using the Freedman Diaconis method.

# %%
vdf["age"].hist()
vdf["age"].hist(h = 5)

# %% [markdown]
# It is possible to change the occurences by another aggregation. The parameters 'method' and 'of' must be changed according to our needs.

# %%
vdf["age"].hist(method = "avg", of = "survived")

# %% [markdown]
# VerticaPy is using the same process for other graphics such as 2D Histograms or Bars.

# %%
vdf.bar(["pclass", "survived"])
vdf.hist(["fare", "pclass"],
         method = "avg",
         of = "survived")

# %% [markdown]
# Pivot Tables are more powerful than histograms or bar charts. They give us aggregated information on all the possible categories.

# %%
vdf.pivot_table(["pclass", "fare"], 
                method = "avg",
                of = "survived")
# Out:
#      "pclass"/"fare"         [0.00;42.69]        [42.69;85.38]   \\
# 1                  1                 0.44    0.663716814159292   \\
# 2                  2    0.425101214574899                 0.25   \\
# 3                  3    0.227987421383648    0.230769230769231   \\
#         [85.38;128.07]      [128.07;170.76]      [170.76;213.45]   \\
# 1    0.787878787878788    0.724137931034483    0.666666666666667   \\
# 2                                                                  \\
# 3                                                                  \\
#      [213.45;256.14]    [256.14;298.83]    [512.28;554.97]
# 1                0.5               0.75                1.0
# 2
# 3
# Rows: 1-3 | Columns: 9

# %% [markdown]
# Box plots are useful to understand variables dispersion.

# %%
vdf.boxplot(columns = ["age", "fare"])
vdf["age"].boxplot()

# %% [markdown]
# It is also possible to understand many patterns using scatter and bubble plots. However, these methods are not using aggregations. That's why VerticaPy will downsample the data before plotting. A parameter 'max_nb_points' can be to use to avoid heavy memory usage during the drawing.

# %%
vdf = vDataFrame("public.iris")
vdf.scatter(["Sepal_Length", "Petal_Width"], 
            catcol = "Species", 
            max_nb_points = 1000)
vdf.scatter(["Sepal_Length", "Petal_Width", "Sepal_Width"], 
            catcol = "Species", 
            max_nb_points = 1000)
vdf.bubble(["Sepal_Length", "Petal_Width"], 
            size_bubble_col = "Sepal_Width",
            catcol = "Species", 
            max_nb_points = 1000)

# %% [markdown]
# Hexbin Plots can be to use to get heatmaps.
#
# They will compute aggregations to get the final results and they are a way to summarize scatter plots.

# %%
vdf.hexbin(["Sepal_Length", "Sepal_Width"], 
            method = "avg", 
            of = "Petal_Width")

# %% [markdown]
# Graphics help us to understand our data to take suitable decisions.
#
# Another important topic is to look at the link between the different variables. That's the main subject of our next lesson !

# %% [markdown]
# ## Responsive Charts

# %% [markdown]
# Install python-highchart first!

# %%
titanic = vDataFrame("titanic")
titanic.hchart(x = "embarked",
               y = "pclass",
               z = "ROUND(AVG(survived), 2)",
               kind = "heatmap")
# Out:
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt; &lt;html lang=&quot;en&quot;&gt; &lt;head&gt; &lt;meta charset=&quot;utf-8&quot; /&gt; &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/highcharts.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/highcharts-more.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/modules/heatmap.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/modules/exporting.js&quot;&gt;&lt;/script&gt; &lt;/head&gt; &lt;body style=&quot;margin:0;padding:0&quot;&gt; &lt;div id=&quot;container&quot; style=&quot;width:600px;height:400px;&quot;&gt;Loading....&lt;/div&gt; &lt;script&gt; $(function(){ Highcharts.setOptions({&quot;global&quot;: {}, &quot;lang&quot;: {}}); var option = {&quot;chart&quot;: {&quot;renderTo&quot;: &quot;container&quot;, &quot;width&quot;: 600, &quot;height&quot;: 400, &quot;type&quot;: &quot;heatmap&quot;, &quot;marginTop&quot;: 40, &quot;marginBottom&quot;: 80, &quot;plotBorderWidth&quot;: 1}, &quot;colors&quot;: [&quot;#263133&quot;, &quot;#FE5016&quot;, &quot;#0073E7&quot;, &quot;#19A26B&quot;, &quot;#FCDB1F&quot;, &quot;#000000&quot;, &quot;#2A6A74&quot;, &quot;#861889&quot;, &quot;#00B4E0&quot;, &quot;#90EE90&quot;, &quot;#FF7F50&quot;, &quot;#B03A89&quot;], &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;drilldown&quot;: {}, &quot;exporting&quot;: {}, &quot;labels&quot;: {}, &quot;legend&quot;: {&quot;align&quot;: &quot;right&quot;, &quot;layout&quot;: &quot;vertical&quot;, &quot;margin&quot;: 0, &quot;verticalAlign&quot;: &quot;top&quot;, &quot;y&quot;: 25, &quot;symbolHeight&quot;: 295.0}, &quot;loading&quot;: {}, &quot;navigation&quot;: {}, &quot;pane&quot;: {}, &quot;plotOptions&quot;: {}, &quot;series&quot;: {}, &quot;subtitle&quot;: {}, &quot;title&quot;: {&quot;text&quot;: &quot;&quot;}, &quot;tooltip&quot;: {&quot;formatter&quot;: function () {return &#x27;&lt;b&gt;[&#x27; + this.series.xAxis.categories[this.point.x] + &#x27;, &#x27; + this.series.yAxis.categories[this.point.y] + &#x27;]&lt;/b&gt;: &#x27; + this.point.value + &#x27;&lt;/b&gt;&#x27;;}}, &quot;xAxis&quot;: {&quot;title&quot;: {&quot;text&quot;: &quot;embarked&quot;}, &quot;categories&quot;: [&quot;C&quot;, &quot;S&quot;, &quot;Q&quot;, &quot;None&quot;]}, &quot;yAxis&quot;: {&quot;title&quot;: {&quot;text&quot;: &quot;pclass&quot;}, &quot;categories&quot;: [1.0, 2.0, 3.0]}, &quot;colorAxis&quot;: {&quot;maxColor&quot;: &quot;#FE5016&quot;, &quot;minColor&quot;: &quot;#FFFFFF&quot;}}; var chart = new Highcharts.Chart(option); var data = [{&quot;data&quot;: [[0, 0, 0.68], [0, 1, 0.56], [0, 2, 0.32], [1, 0, 0.55], [1, 1, 0.4], [1, 2, 0.2], [2, 0, 0.67], [2, 1, 0.29], [2, 2, 0.26], [3, 0, 1.0], [3, 1, null], [3, 2, null]], &quot;type&quot;: &quot;heatmap&quot;, &quot;dataLabels&quot;: {&quot;enabled&quot;: true, &quot;color&quot;: &quot;#000000&quot;}, &quot;name&quot;: &quot;Series 1&quot;, &quot;borderWidth&quot;: 1}]; var dataLen = data.length; for (var ix = 0; ix &lt; dataLen; ix++) { chart.addSeries(data[ix]); } }); &lt;/script&gt; &lt;/body&gt; &lt;/html&gt;" height=400 width=600></iframe>

# %%
# Correlation Matrix
titanic.hchart(kind = "pearson")
# Out:
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt; &lt;html lang=&quot;en&quot;&gt; &lt;head&gt; &lt;meta charset=&quot;utf-8&quot; /&gt; &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/highcharts.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/highcharts-more.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/modules/heatmap.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/modules/exporting.js&quot;&gt;&lt;/script&gt; &lt;/head&gt; &lt;body style=&quot;margin:0;padding:0&quot;&gt; &lt;div id=&quot;container&quot; style=&quot;width:600px;height:400px;&quot;&gt;Loading....&lt;/div&gt; &lt;script&gt; $(function(){ Highcharts.setOptions({&quot;global&quot;: {}, &quot;lang&quot;: {}}); var option = {&quot;chart&quot;: {&quot;renderTo&quot;: &quot;container&quot;, &quot;width&quot;: 600, &quot;height&quot;: 400, &quot;type&quot;: &quot;heatmap&quot;, &quot;marginTop&quot;: 40, &quot;marginBottom&quot;: 80, &quot;plotBorderWidth&quot;: 1}, &quot;colors&quot;: [&quot;#263133&quot;, &quot;#FE5016&quot;, &quot;#0073E7&quot;, &quot;#19A26B&quot;, &quot;#FCDB1F&quot;, &quot;#000000&quot;, &quot;#2A6A74&quot;, &quot;#861889&quot;, &quot;#00B4E0&quot;, &quot;#90EE90&quot;, &quot;#FF7F50&quot;, &quot;#B03A89&quot;], &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;drilldown&quot;: {}, &quot;exporting&quot;: {}, &quot;labels&quot;: {}, &quot;legend&quot;: {&quot;align&quot;: &quot;right&quot;, &quot;layout&quot;: &quot;vertical&quot;, &quot;margin&quot;: 0, &quot;verticalAlign&quot;: &quot;top&quot;, &quot;y&quot;: 25, &quot;symbolHeight&quot;: 295.0}, &quot;loading&quot;: {}, &quot;navigation&quot;: {}, &quot;pane&quot;: {}, &quot;plotOptions&quot;: {}, &quot;series&quot;: {}, &quot;subtitle&quot;: {}, &quot;title&quot;: {&quot;text&quot;: &quot;&quot;}, &quot;tooltip&quot;: {&quot;formatter&quot;: function () {return &#x27;&lt;b&gt;[&#x27; + this.series.xAxis.categories[this.point.x] + &#x27;, &#x27; + this.series.yAxis.categories[this.point.y] + &#x27;]&lt;/b&gt;: &#x27; + this.point.value + &#x27;&lt;/b&gt;&#x27;;}}, &quot;xAxis&quot;: {&quot;title&quot;: {&quot;text&quot;: &quot;&quot;}, &quot;categories&quot;: [&quot;\&quot;pclass\&quot;&quot;, &quot;\&quot;survived\&quot;&quot;, &quot;\&quot;age\&quot;&quot;, &quot;\&quot;sibsp\&quot;&quot;, &quot;\&quot;parch\&quot;&quot;, &quot;\&quot;fare\&quot;&quot;, &quot;\&quot;body\&quot;&quot;]}, &quot;yAxis&quot;: {&quot;title&quot;: {&quot;text&quot;: &quot;&quot;}, &quot;categories&quot;: [&quot;\&quot;pclass\&quot;&quot;, &quot;\&quot;survived\&quot;&quot;, &quot;\&quot;age\&quot;&quot;, &quot;\&quot;sibsp\&quot;&quot;, &quot;\&quot;parch\&quot;&quot;, &quot;\&quot;fare\&quot;&quot;, &quot;\&quot;body\&quot;&quot;]}, &quot;colorAxis&quot;: {&quot;stops&quot;: [[0, &quot;#0073E7&quot;], [0.45, &quot;#FFFFFF&quot;], [0.55, &quot;#FFFFFF&quot;], [1, &quot;#FE5016&quot;]]}}; var chart = new Highcharts.Chart(option); var data = [{&quot;data&quot;: [[0, 0, 1.0], [0, 1, -0.34], [0, 2, -0.4], [0, 3, 0.06], [0, 4, 0.01], [0, 5, -0.56], [0, 6, -0.05], [1, 0, -0.34], [1, 1, 1.0], [1, 2, -0.04], [1, 3, -0.02], [1, 4, 0.09], [1, 5, 0.26], [1, 6, null], [2, 0, -0.4], [2, 1, -0.04], [2, 2, 1.0], [2, 3, -0.25], [2, 4, -0.14], [2, 5, 0.18], [2, 6, 0.06], [3, 0, 0.06], [3, 1, -0.02], [3, 2, -0.25], [3, 3, 1.0], [3, 4, 0.37], [3, 5, 0.15], [3, 6, -0.12], [4, 0, 0.01], [4, 1, 0.09], [4, 2, -0.14], [4, 3, 0.37], [4, 4, 1.0], [4, 5, 0.22], [4, 6, 0.07], [5, 0, -0.56], [5, 1, 0.26], [5, 2, 0.18], [5, 3 ...

# %%
titanic.hchart(x = "pclass",
               y = "AVG(survived)",
               kind = "bar")
# Out:
# <iframe style="border:0;outline:none;overflow:hidden" srcdoc="&lt;!DOCTYPE html&gt; &lt;html lang=&quot;en&quot;&gt; &lt;head&gt; &lt;meta charset=&quot;utf-8&quot; /&gt; &lt;link href=&quot;https://www.highcharts.com/highslide/highslide.css&quot; rel=&quot;stylesheet&quot; /&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/highcharts.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/highcharts-more.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/modules/heatmap.js&quot;&gt;&lt;/script&gt; &lt;script type=&quot;text/javascript&quot; src=&quot;https://code.highcharts.com/6/modules/exporting.js&quot;&gt;&lt;/script&gt; &lt;/head&gt; &lt;body style=&quot;margin:0;padding:0&quot;&gt; &lt;div id=&quot;container&quot; style=&quot;width:600px;height:400px;&quot;&gt;Loading....&lt;/div&gt; &lt;script&gt; $(function(){ Highcharts.setOptions({&quot;global&quot;: {}, &quot;lang&quot;: {}}); var option = {&quot;chart&quot;: {&quot;renderTo&quot;: &quot;container&quot;, &quot;width&quot;: 600, &quot;height&quot;: 400, &quot;inverted&quot;: true}, &quot;colors&quot;: [&quot;#263133&quot;, &quot;#FE5016&quot;, &quot;#0073E7&quot;, &quot;#19A26B&quot;, &quot;#FCDB1F&quot;, &quot;#000000&quot;, &quot;#2A6A74&quot;, &quot;#861889&quot;, &quot;#00B4E0&quot;, &quot;#90EE90&quot;, &quot;#FF7F50&quot;, &quot;#B03A89&quot;], &quot;credits&quot;: {&quot;enabled&quot;: false}, &quot;drilldown&quot;: {}, &quot;exporting&quot;: {}, &quot;labels&quot;: {}, &quot;legend&quot;: {&quot;enabled&quot;: false}, &quot;loading&quot;: {}, &quot;navigation&quot;: {}, &quot;pane&quot;: {}, &quot;plotOptions&quot;: {}, &quot;series&quot;: {}, &quot;subtitle&quot;: {}, &quot;title&quot;: {&quot;text&quot;: &quot;&quot;}, &quot;tooltip&quot;: {&quot;headerFormat&quot;: &quot;&quot;, &quot;pointFormat&quot;: &quot;{point.y}&quot;}, &quot;xAxis&quot;: {&quot;reversed&quot;: false, &quot;title&quot;: {&quot;enabled&quot;: true, &quot;text&quot;: &quot;pclass&quot;}, &quot;maxPadding&quot;: 0.05, &quot;showLastLabel&quot;: true, &quot;categories&quot;: [1.0, 2.0, 3.0]}, &quot;yAxis&quot;: {&quot;title&quot;: {&quot;text&quot;: &quot;AVG&quot;}}}; var chart = new Highcharts.Chart(option); var data = [{&quot;data&quot;: [0.612179487179487, 0.416988416988417, 0.227752639517345], &quot;type&quot;: &quot;bar&quot;, &quot;name&quot;: &quot;AVG&quot;, &quot;colorByPoint&quot;: true}]; var dataLen = data.length; for (var ix = 0; ix &lt; dataLen; ix++) { chart.addSeries(data[ix]); } }); &lt;/script&gt; &lt;/body&gt; &lt;/html&gt;" height=400 width=600></iframe>
